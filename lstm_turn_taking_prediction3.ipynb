# %% [markdown]
# <a href="https://colab.research.google.com/github/ziadcoolio/lstm_turn_taking_prediction/blob/main/lstm_turn_taking_prediction3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mattroddy/lstm_turn_taking_prediction
# Out:
# Cloning into 'lstm_turn_taking_prediction'...
# remote: Enumerating objects: 771, done.
# remote: Total 771 (delta 0), reused 0 (delta 0), pack-reused 771 (from 1)
# Receiving objects: 100% (771/771), 19.42 MiB | 14.21 MiB/s, done.
# Resolving deltas: 100% (228/228), done.

# %%
# %cd lstm_turn_taking_prediction/data
#Convert the script to Unix format
# !sed -i 's/\r//' maptaskBuild-213932-Tue-Sep-10-2024.wget.sh
# !sh 'maptaskBuild-213932-Tue-Sep-10-2024.wget.sh'
# Out:
# /content/lstm_turn_taking_prediction/data
# --2024-09-11 20:39:02--  https://groups.inf.ed.ac.uk/maptask/signals/dialogues/q1nc1.mix.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89009056 (85M) [audio/x-wav]
# Saving to: ‘signals/dialogues/q1nc1.mix.wav’
#
# q1nc1.mix.wav       100%[===================>]  84.88M  10.4MB/s    in 9.4s
#
# 2024-09-11 20:39:13 (9.00 MB/s) - ‘signals/dialogues/q1nc1.mix.wav’ saved [89009056/89009056]
#
# --2024-09-11 20:39:13--  https://groups.inf.ed.ac.uk/maptask/signals/dialogues/q1nc2.mix.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74114116 (71M) [audio/x-wav]
# ...

# %%
# !wget http://groups.inf.ed.ac.uk/maptask/hcrcmaptask.nxtformatv2-1.zip
# !unzip hcrcmaptask.nxtformatv2-1.zip
# !rm hcrcmaptask.nxtformatv2-1.zip
# %cd ..
# Out:
# --2024-09-11 20:47:00--  http://groups.inf.ed.ac.uk/maptask/hcrcmaptask.nxtformatv2-1.zip
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://groups.inf.ed.ac.uk/maptask/hcrcmaptask.nxtformatv2-1.zip [following]
# --2024-09-11 20:47:01--  https://groups.inf.ed.ac.uk/maptask/hcrcmaptask.nxtformatv2-1.zip
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12206088 (12M) [application/zip]
# Saving to: ‘hcrcmaptask.nxtformatv2-1.zip’
#
# hcrcmaptask.nxtform 100%[===================>]  11.64M  4.39MB/s    in 2.6s
#
# 2024-09-11 20:47:04 (4.39 MB/s) - ‘hcrcmaptask.nxtformatv2-1.zip’ saved [12206088/12206088]
#
# Archive:  hcrcmaptask.nxtformatv2-1.zip
#    creating: maptaskv2-1/
# ...

# %%
# !apt-get install sox
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3 libwavpack1
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3 libwavpack1 sox
# 0 upgraded, 7 newly installed, 0 to remove and 49 not upgraded.
# Need to get 617 kB of archives.
# After this operation, 1,764 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1 [240 kB]
# ...

# %%
# !sh scripts/split_channels.sh
# Out:
# mkdir: cannot create directory ‘./signals/dialogues_mono’: File exists
# VAR: ./signals/dialogues/q6nc1.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q6nc1.g.wav
# VAR: ./signals/dialogues/q8nc4.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q8nc4.g.wav
# VAR: ./signals/dialogues/q8nc3.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q8nc3.g.wav
# VAR: ./signals/dialogues/q1nc5.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q1nc5.g.wav
# VAR: ./signals/dialogues/q3nc2.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q3nc2.g.wav
# VAR: ./signals/dialogues/q4nc1.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q4nc1.g.wav
# VAR: ./signals/dialogues/q4nc5.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q4nc5.g.wav
# VAR: ./signals/dialogues/q1nc1.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q1nc1.g.wav
# VAR: ./signals/dialogues/q4nc8.mix.wav
# LEFTCHANNEL: ./signals/dialogues_mono/q4nc8.g.wav
# VAR: ./signals/dialogues/q5nc7.mix.wav
# ...
